# %% [markdown]
# Code provided by Library of Congress Chronicling American API guide found here:
# https://libraryofcongress.github.io/data-exploration/loc.gov%20JSON%20API/Chronicling_America/ChronAm_analyzing_specific_titles_limit_results.html

# %%
import time
import re
import json
from urllib.request import urlopen
import requests
import pandas as pd
import pprint

# %%
# Test to get all search results:
searchURLTest = "https://www.loc.gov/collections/chronicling-america/?end_date=1930-12-31&ops=~10!PHRASE&qs=Los+Angeles+oil!Los+Angeles&searchType=advanced&sp=1&start_date=1890-01-01&fo=json"
numberOfResults = 0

def get_item_ids_test(url, items=[], conditional='True'):
    global numberOfResults
    # Check that the query URL is not an item or resource link.
    exclude = ["loc.gov/item","loc.gov/resource"]
    if any(string in url for string in exclude):
        raise NameError('Your URL points directly to an item or '
                        'resource page (you can tell because "item" '
                        'or "resource" is in the URL). Please use '
                        'a search URL instead. For example, instead '
                        'of \"https://www.loc.gov/item/2009581123/\", '
                        'try \"https://www.loc.gov/maps/?q=2009581123\". ')

    # request pages of 100 results at a time
    params = {"fo": "json", "c": 100, "at": "results,pagination"}
    call = requests.get(url, params=params)
    # Check that the API request was successful
    if (call.status_code==200) & ('json' in call.headers.get('content-type')):
        data = call.json()
        results = data['results'] # deleted the top 20 limit
        for result in results:
            # Filter out anything that's a collection or web page
            filter_out = ("collection" in result.get("original_format")) \
                    or ("web page" in result.get("original_format")) \
                    or (eval(conditional)==False)
            if not filter_out:
                # Get the link to the item record
                if result.get("id"):
                    item = result.get("id")
                    # Filter out links to Catalog or other platforms
                    if item.startswith("http://www.loc.gov/resource"):
                      resource = item  # Assign item to resource
                      items.append(resource)
                    if item.startswith("http://www.loc.gov/item"):
                      items.append(item)
                numberOfResults += 1
        # Repeat the loop on the next page, unless we're on the last page.
        if data["pagination"]["next"] is not None:
            next_url = data["pagination"]["next"]
            print(f"Total number of pages: {data['pagination']['total']}")
            get_item_ids_test(next_url, items, conditional)

        return items
    else:
            print('There was a problem. Try running the cell again, or check your searchURL.')

# Generate a list of records found from performing a query and save these Item IDs. (Create ids_list based on items found in the searchURL result)
ids_list_test = get_item_ids_test(searchURLTest, items=[])

# Add 'fo=json' to the end of each row in ids_list (All individual ids from from the ids_list are now listed in JSON format in new_ids)
ids_list_json_test = []
for id in ids_list_test:
  if not id.endswith('&fo=json'):
    id += '&fo=json'
  ids_list_json_test.append(id)
ids = ids_list_json_test

print('\nSuccess! Your API Search Query found '+str(len(ids_list_json_test))+' related newspaper pages. Proceed to the next step')
# Out:
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
# Total number of pages: 292
#
# Success! Your API Search Query found 29143 related newspaper pages. Proceed to the next step

# %%
# Create a list of dictionaries to store the item metadata
item_metadata_list = []

counter = 0
# Iterate over the list of item IDs
for item_id in ids_list_json_test:
  item_response = requests.get(item_id)

  # Check if the API call was successful and Parse the JSON response
  if item_response.status_code == 200:
    # Iterate over the ids_list_json list and extract the relevant metadata from each dictionary.
    item_data = item_response.json()
    if 'location_city' not in item_data['item']:
      continue

    # Extract the relevant item metadata
    Newspaper_Title = item_data['item']['newspaper_title']
    Issue_Date = item_data['item']['date']
    Page = item_data['pagination']['current']
    State = item_data['item']['location_state']
    City = item_data['item']['location_city']
    LCCN = item_data['item']['number_lccn']
    Contributor = item_data['item']['contributor_names']
    Batch = item_data['item']['batch']
    pdf = item_data['resource']['pdf']

    # Add the item metadata to the list
    item_metadata_list.append({
        'Newspaper Title': Newspaper_Title,
        'Issue Date': Issue_Date,
        'Page Number': Page,
        'LCCN': LCCN,
        'City': City,
        'State': State,
        'Contributor': Contributor,
        'Batch': Batch,
        'PDF Link': pdf,
    })
    counter += 1
    print(f"Processed {counter} results.")
    

# Change date format to MM-DD-YYYY
for item in item_metadata_list:
  item['Issue Date'] = pd.to_datetime(item['Issue Date']).strftime('%m-%d-%Y')

# Create a Pandas DataFrame from the list of dictionaries
df = pd.DataFrame(item_metadata_list)

print('\nSuccess! Ready to proceed to the next step!')
# Out:
# Processed 1 results.
# Processed 2 results.
# Processed 3 results.
# Processed 4 results.
# Processed 5 results.
# Processed 6 results.
# Processed 7 results.
# Processed 8 results.
# Processed 9 results.
# Processed 10 results.
# Processed 11 results.
# Processed 12 results.
# Processed 13 results.
# Processed 14 results.
# Processed 15 results.
# Processed 16 results.
# Processed 17 results.
# Processed 18 results.
# Processed 19 results.
# Processed 20 results.
# Processed 21 results.
# Processed 22 results.
# Processed 23 results.
# Processed 24 results.
# Processed 25 results.
# Processed 26 results.
# Processed 27 results.
# Processed 28 results.
# Processed 29 results.
# Processed 30 results.
# Processed 31 results.
# Processed 32 results.
# Processed 33 results.
# Processed 34 results.
# Processed 35 results.
# Processed 36 results.
# Processed 37 results.
# Processed 38 results.
# Processed 39 results.
# Processed 40 results.
# Processed 41 results.
# Processed 42 results.
# Processed 43 results.
# Processed 44 results.
# Processed 45 results.
# Processed 46 results.
# Processed 47 results.
# Processed 48 results.
# Processed 49 results.
# Processed 50 results.
# Processed 51 results.
# Processed 52 results.
# Processed 53 results.
# Processed 54 results.
# Processed 55 results.
# Processed 56 results.
# Processed 57 results.
# Processed 58 results.
# Processed 59 results.
# Processed 60 results.
# Processed 61 results.
# Processed 62 results.
# Processed 63 results.
# Processed 64 results.
# Processed 65 results.
# Processed 66 results.
# Processed 67 results.
# Processed 68 results.
# Processed 69 results.
# Processed 70 results.
# Processed 71 results.
# Processed 72 results.
# Processed 73 results.
# Processed 74 results.
# Processed 75 results.
# Processed 76 results.
# Processed 77 results.
# Processed 78 results.
# Processed 79 results.
# Processed 80 results.
# Processed 81 results.
# Processed 82 results.
# Processed 83 results.
# Processed 84 results.
# Processed 85 results.
# Processed 86 results.
# Processed 87 results.
# Processed 88 results.
# Processed 89 results.
# Processed 90 results.
# Processed 91 results.
# Processed 92 results.
# Processed 93 results.
# Processed 94 results.
# Processed 95 results.
# Processed 96 results.
# Processed 97 results.
# Processed 98 results.
# Processed 99 results.
# Processed 100 results.
# Processed 101 results.
# Processed 102 results.
# Processed 103 results.
# Processed 104 results.
# Processed 105 results.
# Processed 106 results.
# Processed 107 results.
# Processed 108 results.
# Processed 109 results.
# Processed 110 results.
# Processed 111 results.
# Processed 112 results.
# Processed 113 results.
# Processed 114 results.
# Processed 115 results.
# Processed 116 results.
# Processed 117 results.
# Processed 118 results.
# Processed 119 results.
# Processed 120 results.
# Processed 121 results.
# Processed 122 results.
# Processed 123 results.
# Processed 124 results.
# Processed 125 results.
# Processed 126 results.
# Processed 127 results.
# Processed 128 results.
# Processed 129 results.
# Processed 130 results.
# Processed 131 results.
# Processed 132 results.
# Processed 133 results.
# Processed 134 results.
# Processed 135 results.
# Processed 136 results.
# Processed 137 results.
# Processed 138 results.
# Processed 139 results.
# Processed 140 results.
# Processed 141 results.
# Processed 142 results.
# Processed 143 results.
# Processed 144 results.
# Processed 145 results.
# Processed 146 results.
# Processed 147 results.
# Processed 148 results.
# Processed 149 results.
# Processed 150 results.
# Processed 151 results.
# Processed 152 results.
# Processed 153 results.
# Processed 154 results.
# Processed 155 results.
# Processed 156 results.
# Processed 157 results.
# Processed 158 results.
# Processed 159 results.
# Processed 160 results.
# Processed 161 results.
# Processed 162 results.
# Processed 163 results.
# Processed 164 results.
# Processed 165 results.
# Processed 166 results.
# Processed 167 results.
# Processed 168 results.
# Processed 169 results.
# Processed 170 results.
# Processed 171 results.
# Processed 172 results.
# Processed 173 results.
# Processed 174 results.
# Processed 175 results.
# Processed 176 results.
# Processed 177 results.
# Processed 178 results.
# Processed 179 results.
# Processed 180 results.
# Processed 181 results.
# Processed 182 results.
# Processed 183 results.
# Processed 184 results.
# Processed 185 results.
# Processed 186 results.
# Processed 187 results.
# Processed 188 results.
# Processed 189 results.
# Processed 190 results.
# Processed 191 results.
# Processed 192 results.
# Processed 193 results.
# Processed 194 results.
# Processed 195 results.
# Processed 196 results.
# Processed 197 results.
# Processed 198 results.
# Processed 199 results.
# Processed 200 results.
# Processed 201 results.
# Processed 202 results.
# Processed 203 results.
# Processed 204 results.
# Processed 205 results.
# Processed 206 results.
# Processed 207 results.
# Processed 208 results.
# Processed 209 results.
# Processed 210 results.
# Processed 211 results.
# Processed 212 results.
# Processed 213 results.
# Processed 214 results.
# Processed 215 results.
# Processed 216 results.
# Processed 217 results.
# Processed 218 results.
# Processed 219 results.
# Processed 220 results.
# Processed 221 results.
# Processed 222 results.
# Processed 223 results.
# Processed 224 results.
# Processed 225 results.
# Processed 226 results.
# Processed 227 results.
# Processed 228 results.
# Processed 229 results.
# Processed 230 results.
# Processed 231 results.
# Processed 232 results.
# Processed 233 results.
# Processed 234 results.
# Processed 235 results.
# Processed 236 results.
# Processed 237 results.
# Processed 238 results.
# Processed 239 results.
# Processed 240 results.
# Processed 241 results.
# Processed 242 results.
# Processed 243 results.
# Processed 244 results.
# Processed 245 results.
# Processed 246 results.
# Processed 247 results.
# Processed 248 results.
# Processed 249 results.
# Processed 250 results.
# Processed 251 results.
# Processed 252 results.
# Processed 253 results.
# Processed 254 results.
# Processed 255 results.
# Processed 256 results.
# Processed 257 results.
# Processed 258 results.
# Processed 259 results.
# Processed 260 results.
# Processed 261 results.
# Processed 262 results.
# Processed 263 results.
# Processed 264 results.
# Processed 265 results.
# Processed 266 results.
# Processed 267 results.
# Processed 268 results.
# Processed 269 results.
# Processed 270 results.
# Processed 271 results.
# Processed 272 results.
# Processed 273 results.
# Processed 274 results.
# Processed 275 results.
# Processed 276 results.
# Processed 277 results.
# Processed 278 results.
# Processed 279 results.
# Processed 280 results.
# Processed 281 results.
# Processed 282 results.
# Processed 283 results.
# Processed 284 results.
# Processed 285 results.
# Processed 286 results.
# Processed 287 results.
# Processed 288 results.
# Processed 289 results.
# Processed 290 results.
# Processed 291 results.
# Processed 292 results.
# Processed 293 results.
# Processed 294 results.
# Processed 295 results.
# Processed 296 results.
# Processed 297 results.
# Processed 298 results.
# Processed 299 results.
# Processed 300 results.
# Processed 301 results.
# Processed 302 results.
# Processed 303 results.
# Processed 304 results.
# Processed 305 results.
# Processed 306 results.
# Processed 307 results.
# Processed 308 results.
# Processed 309 results.
# Processed 310 results.
# Processed 311 results.
# Processed 312 results.
# Processed 313 results.
# Processed 314 results.
# Processed 315 results.
# Processed 316 results.
# Processed 317 results.
# Processed 318 results.
# Processed 319 results.
# Processed 320 results.
# Processed 321 results.
# Processed 322 results.
# Processed 323 results.
# Processed 324 results.
# Processed 325 results.
# Processed 326 results.
# Processed 327 results.
# Processed 328 results.
# Processed 329 results.
# Processed 330 results.
# Processed 331 results.
# Processed 332 results.
# Processed 333 results.
# Processed 334 results.
# Processed 335 results.
# Processed 336 results.
# Processed 337 results.
# Processed 338 results.
# Processed 339 results.
# Processed 340 results.
# Processed 341 results.
# Processed 342 results.
# Processed 343 results.
# Processed 344 results.
# Processed 345 results.
# Processed 346 results.
# Processed 347 results.
# Processed 348 results.
# Processed 349 results.
# Processed 350 results.
# Processed 351 results.
# Processed 352 results.
# Processed 353 results.
# Processed 354 results.
# Processed 355 results.
# Processed 356 results.
# Processed 357 results.
# Processed 358 results.
# Processed 359 results.
# Processed 360 results.
# Processed 361 results.
# Processed 362 results.
# Processed 363 results.
# Processed 364 results.
# Processed 365 results.
# Processed 366 results.
# Processed 367 results.
# Processed 368 results.
# Processed 369 results.
# Processed 370 results.
# Processed 371 results.
# Processed 372 results.
# Processed 373 results.
# Processed 374 results.
# Processed 375 results.
# Processed 376 results.
# Processed 377 results.
# Processed 378 results.
# Processed 379 results.
# Processed 380 results.
# Processed 381 results.
# Processed 382 results.
# Processed 383 results.
# Processed 384 results.
# Processed 385 results.
# Processed 386 results.
# Processed 387 results.
# Processed 388 results.
# Processed 389 results.
# Processed 390 results.
# Processed 391 results.
# Processed 392 results.
# Processed 393 results.
# Processed 394 results.
# Processed 395 results.
# Processed 396 results.
# Processed 397 results.
# Processed 398 results.
# Processed 399 results.
# Processed 400 results.
# Processed 401 results.
# Processed 402 results.
# Processed 403 results.
# Processed 404 results.
# Processed 405 results.
# Processed 406 results.
# Processed 407 results.
# Processed 408 results.
# Processed 409 results.
# Processed 410 results.
# Processed 411 results.
# Processed 412 results.
# Processed 413 results.
# Processed 414 results.
# Processed 415 results.
# Processed 416 results.
# Processed 417 results.
# Processed 418 results.
# Processed 419 results.
# Processed 420 results.
# Processed 421 results.
# Processed 422 results.
# Processed 423 results.
# Processed 424 results.
# Processed 425 results.
# Processed 426 results.
# Processed 427 results.
# Processed 428 results.
# Processed 429 results.
# Processed 430 results.
# Processed 431 results.
# Processed 432 results.
# Processed 433 results.
# Processed 434 results.
# Processed 435 results.
# Processed 436 results.
# Processed 437 results.
# Processed 438 results.
# Processed 439 results.
# Processed 440 results.
# Processed 441 results.
# Processed 442 results.
# Processed 443 results.
# Processed 444 results.
# Processed 445 results.
# Processed 446 results.
# Processed 447 results.
# Processed 448 results.
# Processed 449 results.
# Processed 450 results.
# Processed 451 results.
# Processed 452 results.
# Processed 453 results.
# Processed 454 results.
# Processed 455 results.
# Processed 456 results.
# Processed 457 results.
# Processed 458 results.
# Processed 459 results.
# Processed 460 results.
# Processed 461 results.
# Processed 462 results.
# Processed 463 results.
# Processed 464 results.
# Processed 465 results.
# Processed 466 results.
# Processed 467 results.
# Processed 468 results.
# Processed 469 results.
# Processed 470 results.
# Processed 471 results.
# Processed 472 results.
# Processed 473 results.
# Processed 474 results.
# Processed 475 results.
# Processed 476 results.
# Processed 477 results.
# Processed 478 results.
# Processed 479 results.
# Processed 480 results.
# Processed 481 results.
# Processed 482 results.
# Processed 483 results.
# Processed 484 results.
# Processed 485 results.
# Processed 486 results.
# Processed 487 results.
# Processed 488 results.
# Processed 489 results.
# Processed 490 results.
# Processed 491 results.
# Processed 492 results.
# Processed 493 results.
# Processed 494 results.
# Processed 495 results.
# Processed 496 results.
# Processed 497 results.
# Processed 498 results.
# Processed 499 results.
# Processed 500 results.
# Processed 501 results.
# Processed 502 results.
# Processed 503 results.
# Processed 504 results.
# Processed 505 results.
# Processed 506 results.
# Processed 507 results.
# Processed 508 results.
# Processed 509 results.
# Processed 510 results.
# Processed 511 results.
# Processed 512 results.
# Processed 513 results.
# Processed 514 results.
# Processed 515 results.
# Processed 516 results.
# Processed 517 results.
# Processed 518 results.
# Processed 519 results.
# Processed 520 results.
# Processed 521 results.
# Processed 522 results.
# Processed 523 results.
# Processed 524 results.
# Processed 525 results.
# Processed 526 results.
# Processed 527 results.
# Processed 528 results.
# Processed 529 results.
# Processed 530 results.
# Processed 531 results.
# Processed 532 results.
# Processed 533 results.
# Processed 534 results.
# Processed 535 results.
# Processed 536 results.
# Processed 537 results.
# Processed 538 results.
# Processed 539 results.
# Processed 540 results.
# Processed 541 results.
# Processed 542 results.
# Processed 543 results.
# Processed 544 results.
# Processed 545 results.
# Processed 546 results.
# Processed 547 results.
# Processed 548 results.
# Processed 549 results.
# Processed 550 results.
# Processed 551 results.
# Processed 552 results.
# Processed 553 results.
# Processed 554 results.
# Processed 555 results.
# Processed 556 results.
# Processed 557 results.
# Processed 558 results.
# Processed 559 results.
# Processed 560 results.
# Processed 561 results.
# Processed 562 results.
# Processed 563 results.
# Processed 564 results.
# Processed 565 results.
# Processed 566 results.
# Processed 567 results.
# Processed 568 results.
# Processed 569 results.
# Processed 570 results.
# Processed 571 results.
# Processed 572 results.
# Processed 573 results.
# Processed 574 results.
# Processed 575 results.
# Processed 576 results.
# Processed 577 results.
# Processed 578 results.
# Processed 579 results.
# Processed 580 results.
# Processed 581 results.
# Processed 582 results.
# Processed 583 results.
# Processed 584 results.
# Processed 585 results.
# Processed 586 results.
# Processed 587 results.
# Processed 588 results.
# Processed 589 results.
# Processed 590 results.
# Processed 591 results.
# Processed 592 results.
# Processed 593 results.
# Processed 594 results.
# Processed 595 results.
# Processed 596 results.
# Processed 597 results.
# Processed 598 results.
# Processed 599 results.
# Processed 600 results.
# Processed 601 results.
# Processed 602 results.
# Processed 603 results.
# Processed 604 results.
# Processed 605 results.
# Processed 606 results.
# Processed 607 results.
# Processed 608 results.
# Processed 609 results.
# Processed 610 results.
# Processed 611 results.
# Processed 612 results.
# Processed 613 results.
# Processed 614 results.
# Processed 615 results.
# Processed 616 results.
# Processed 617 results.
# Processed 618 results.
# Processed 619 results.
# Processed 620 results.
# Processed 621 results.
# Processed 622 results.
# Processed 623 results.
# Processed 624 results.
# Processed 625 results.
# Processed 626 results.
# Processed 627 results.
# Processed 628 results.
# Processed 629 results.
# Processed 630 results.
# Processed 631 results.
# Processed 632 results.
# Processed 633 results.
# Processed 634 results.
# Processed 635 results.
# Processed 636 results.
# Processed 637 results.
# Processed 638 results.
# Processed 639 results.
# Processed 640 results.
# Processed 641 results.
# Processed 642 results.
# Processed 643 results.
# Processed 644 results.
# Processed 645 results.
# Processed 646 results.
# Processed 647 results.
# Processed 648 results.
# Processed 649 results.
# Processed 650 results.
# Processed 651 results.
# Processed 652 results.
# Processed 653 results.
# Processed 654 results.
# Processed 655 results.
# Processed 656 results.
# Processed 657 results.
# Processed 658 results.
# Processed 659 results.
# Processed 660 results.
# Processed 661 results.
# Processed 662 results.
# Processed 663 results.
# Processed 664 results.
# Processed 665 results.
# Processed 666 results.
# Processed 667 results.
# Processed 668 results.
# Processed 669 results.
# Processed 670 results.
# Processed 671 results.
# Processed 672 results.
# Processed 673 results.
# Processed 674 results.
# Processed 675 results.
# Processed 676 results.
# Processed 677 results.
# Processed 678 results.
# Processed 679 results.
# Processed 680 results.
# Processed 681 results.
# Processed 682 results.
# Processed 683 results.
# Processed 684 results.
# Processed 685 results.
# Processed 686 results.
# Processed 687 results.
# Processed 688 results.
# Processed 689 results.
# Processed 690 results.
# Processed 691 results.
# Processed 692 results.
# Processed 693 results.
# Processed 694 results.
# Processed 695 results.
# Processed 696 results.
# Processed 697 results.
# Processed 698 results.
# Processed 699 results.
# Processed 700 results.
# Processed 701 results.
# Processed 702 results.
# Processed 703 results.
# Processed 704 results.
# Processed 705 results.
# Processed 706 results.
# Processed 707 results.
# Processed 708 results.
# Processed 709 results.
# Processed 710 results.
# Processed 711 results.
# Processed 712 results.
# Processed 713 results.
# Processed 714 results.
# Processed 715 results.
# Processed 716 results.
# Processed 717 results.
# Processed 718 results.
# Processed 719 results.
# Processed 720 results.
# Processed 721 results.
# Processed 722 results.
# Processed 723 results.
# Processed 724 results.
# Processed 725 results.
# Processed 726 results.
# Processed 727 results.
# Processed 728 results.
# Processed 729 results.
# Processed 730 results.
# Processed 731 results.
# Processed 732 results.
# Processed 733 results.
# Processed 734 results.
# Processed 735 results.
# Processed 736 results.
# Processed 737 results.
# Processed 738 results.
# Processed 739 results.
# Processed 740 results.
# Processed 741 results.
# Processed 742 results.
# Processed 743 results.
# Processed 744 results.
# Processed 745 results.
# Processed 746 results.
# Processed 747 results.
# Processed 748 results.
# Processed 749 results.
# Processed 750 results.
# Processed 751 results.
# Processed 752 results.
# Processed 753 results.
# Processed 754 results.
# Processed 755 results.
# Processed 756 results.
# Processed 757 results.
# Processed 758 results.
# Processed 759 results.
# Processed 760 results.
# Processed 761 results.
# Processed 762 results.
# Processed 763 results.
# Processed 764 results.
# Processed 765 results.
# Processed 766 results.
# Processed 767 results.
# Processed 768 results.
# Processed 769 results.
# Processed 770 results.
# Processed 771 results.
# Processed 772 results.
# Processed 773 results.
# Processed 774 results.
# Processed 775 results.
# Processed 776 results.
# Processed 777 results.
# Processed 778 results.
# Processed 779 results.
# Processed 780 results.
# Processed 781 results.
# Processed 782 results.
# Processed 783 results.
# Processed 784 results.
# Processed 785 results.
# Processed 786 results.
# Processed 787 results.
# Processed 788 results.
# Processed 789 results.
# Processed 790 results.
# Processed 791 results.
# Processed 792 results.
# Processed 793 results.
# Processed 794 results.
# Processed 795 results.
# Processed 796 results.
# Processed 797 results.
# Processed 798 results.
# Processed 799 results.
# Processed 800 results.
# Processed 801 results.
# Processed 802 results.
# Processed 803 results.
# Processed 804 results.
# Processed 805 results.
# Processed 806 results.
# Processed 807 results.
# Processed 808 results.
# Processed 809 results.
# Processed 810 results.
# Processed 811 results.
# Processed 812 results.
# Processed 813 results.
# Processed 814 results.
# Processed 815 results.
# Processed 816 results.
# Processed 817 results.
# Processed 818 results.
# Processed 819 results.
# Processed 820 results.
# Processed 821 results.
# Processed 822 results.
# Processed 823 results.
# Processed 824 results.
# Processed 825 results.
# Processed 826 results.
# Processed 827 results.
# Processed 828 results.
# Processed 829 results.
# Processed 830 results.
# Processed 831 results.
# Processed 832 results.
# Processed 833 results.
# Processed 834 results.
# Processed 835 results.
# Processed 836 results.
# Processed 837 results.
# Processed 838 results.
# Processed 839 results.
# Processed 840 results.
# Processed 841 results.
# Processed 842 results.
# Processed 843 results.
# Processed 844 results.
# Processed 845 results.
# Processed 846 results.
# Processed 847 results.
# Processed 848 results.
# Processed 849 results.
# Processed 850 results.
# Processed 851 results.
# Processed 852 results.
# Processed 853 results.
# Processed 854 results.
# Processed 855 results.
# Processed 856 results.
# Processed 857 results.
# Processed 858 results.
# Processed 859 results.
# Processed 860 results.
# Processed 861 results.
# Processed 862 results.
# Processed 863 results.
# Processed 864 results.
# Processed 865 results.
# Processed 866 results.
# Processed 867 results.
# Processed 868 results.
# Processed 869 results.
# Processed 870 results.
# Processed 871 results.
# Processed 872 results.
# Processed 873 results.
# Processed 874 results.
# Processed 875 results.
# Processed 876 results.
# Processed 877 results.
# Processed 878 results.
# Processed 879 results.
# Processed 880 results.
# Processed 881 results.
# Processed 882 results.
# Processed 883 results.
# Processed 884 results.
# Processed 885 results.
# Processed 886 results.
# Processed 887 results.
# Processed 888 results.
# Processed 889 results.
# Processed 890 results.
# Processed 891 results.
# Processed 892 results.
# Processed 893 results.
# Processed 894 results.
# Processed 895 results.
# Processed 896 results.
# Processed 897 results.
# Processed 898 results.
# Processed 899 results.
# Processed 900 results.
# Processed 901 results.
# Processed 902 results.
# Processed 903 results.
# Processed 904 results.
# Processed 905 results.
# Processed 906 results.
# Processed 907 results.
# Processed 908 results.
# Processed 909 results.
# Processed 910 results.
# Processed 911 results.
# Processed 912 results.
# Processed 913 results.
# Processed 914 results.
# Processed 915 results.
# Processed 916 results.
# Processed 917 results.
# Processed 918 results.
# Processed 919 results.
# Processed 920 results.
# Processed 921 results.
# Processed 922 results.
# Processed 923 results.
# Processed 924 results.
# Processed 925 results.
# Processed 926 results.
# Processed 927 results.
# Processed 928 results.
# Processed 929 results.
# Processed 930 results.
# Processed 931 results.
# Processed 932 results.
# Processed 933 results.
# Processed 934 results.
# Processed 935 results.
# Processed 936 results.
# Processed 937 results.
# Processed 938 results.
# Processed 939 results.
# Processed 940 results.
# Processed 941 results.
# Processed 942 results.
# Processed 943 results.
# Processed 944 results.
# Processed 945 results.
# Processed 946 results.
# Processed 947 results.
# Processed 948 results.
# Processed 949 results.
# Processed 950 results.
# Processed 951 results.
# Processed 952 results.
# Processed 953 results.
# Processed 954 results.
# Processed 955 results.
# Processed 956 results.
# Processed 957 results.
# Processed 958 results.
# Processed 959 results.
# Processed 960 results.
# Processed 961 results.
# Processed 962 results.
# Processed 963 results.
# Processed 964 results.
# Processed 965 results.
# Processed 966 results.
# Processed 967 results.
# Processed 968 results.
# Processed 969 results.
# Processed 970 results.
# Processed 971 results.
# Processed 972 results.
# Processed 973 results.
# Processed 974 results.
# Processed 975 results.
# Processed 976 results.
# Processed 977 results.
# Processed 978 results.
# Processed 979 results.
# Processed 980 results.
# Processed 981 results.
# Processed 982 results.
# Processed 983 results.
# Processed 984 results.
# Processed 985 results.
# Processed 986 results.
# Processed 987 results.
# Processed 988 results.
# Processed 989 results.
# Processed 990 results.
# Processed 991 results.
# Processed 992 results.
# Processed 993 results.
# Processed 994 results.
# Processed 995 results.
# Processed 996 results.
# Processed 997 results.
# Processed 998 results.
# Processed 999 results.
# Processed 1000 results.
# Processed 1001 results.
# Processed 1002 results.
# Processed 1003 results.
# Processed 1004 results.
# Processed 1415 results.
# Processed 1416 results.
# Processed 1417 results.
# Processed 1418 results.
# Processed 1419 results.
# Processed 1420 results.
# Processed 1421 results.
# Processed 1422 results.
# Processed 1423 results.
# Processed 1424 results.
# Processed 1425 results.
# Processed 1426 results.
# Processed 1427 results.
# Processed 1428 results.
# Processed 1429 results.
# Processed 1430 results.
# Processed 1431 results.
# Processed 1432 results.
# Processed 1433 results.
# Processed 1434 results.
# Processed 1435 results.
# Processed 1436 results.
# Processed 1437 results.
# Processed 1438 results.
# Processed 1439 results.
# Processed 1440 results.
# Processed 1441 results.
# Processed 1442 results.
# Processed 1443 results.
# Processed 1444 results.
# Processed 1445 results.
# Processed 1446 results.
# Processed 1447 results.
# Processed 1448 results.
# Processed 1449 results.
# Processed 1450 results.
# Processed 1451 results.
# Processed 1452 results.
# Processed 1453 results.
# Processed 1454 results.
# Processed 1455 results.
# Processed 1456 results.
# Processed 1457 results.
# Processed 1458 results.
# Processed 1459 results.
# Processed 1460 results.
# Processed 1461 results.
# Processed 1462 results.
# Processed 1463 results.
# Processed 1464 results.
# Processed 1465 results.
# Processed 1466 results.
# Processed 1467 results.
# Processed 1468 results.
# Processed 1469 results.
# Processed 1470 results.
# Processed 1471 results.
# Processed 1472 results.
# Processed 1473 results.
# Processed 1474 results.
# Processed 1475 results.
# Processed 1476 results.
# Processed 1477 results.
# Processed 1478 results.
# Processed 1479 results.
# Processed 1480 results.
# Processed 1481 results.
# Processed 1482 results.
# Processed 1483 results.
# Processed 1484 results.
# Processed 1485 results.
# Processed 1486 results.
# Processed 1487 results.
# Processed 1488 results.
# Processed 1489 results.
# Processed 1490 results.
# Processed 1491 results.
# Processed 1492 results.
# Processed 1493 results.
# Processed 1494 results.
# Processed 1495 results.
# Processed 1496 results.
# Processed 1497 results.
# Processed 1498 results.
# Processed 1499 results.
# Processed 1500 results.
# Processed 1501 results.
# Processed 1502 results.
# Processed 1503 results.
# Processed 1504 results.
# Processed 1505 results.
# Processed 1506 results.
# Processed 1507 results.
# Processed 1508 results.
# Processed 1509 results.
# Processed 1510 results.
# Processed 1511 results.
# Processed 1512 results.
# Processed 1513 results.
# Processed 1514 results.
# Processed 1515 results.
# Processed 1516 results.
# Processed 1517 results.
# Processed 1518 results.
# Processed 1519 results.
# Processed 1520 results.
# Processed 1521 results.
# Processed 1522 results.
# Processed 1523 results.
# Processed 1524 results.
# Processed 1525 results.
# Processed 1526 results.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       5 # Iterate over the list of item IDs
#       6 for item_id in ids_list_json_test:
# ----> 7   item_response = requests.get(item_id)
#       9   # Check if the API call was successful and Parse the JSON response
#      10   if item_response.status_code == 200:
#      11     # Iterate over the ids_list_json list and extract the relevant metadata from each dictionary.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:725, in Session.send(self, request, **kwargs)
#     722 if allow_redirects:
#     723     # Redirect resolving generator.
#     724     gen = self.resolve_redirects(r, request, **kwargs)
# --> 725     history = [resp for resp in gen]
#     726 else:
#     727     history = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:725, in <listcomp>(.0)
#     722 if allow_redirects:
#     723     # Redirect resolving generator.
#     724     gen = self.resolve_redirects(r, request, **kwargs)
# --> 725     history = [resp for resp in gen]
#     726 else:
#     727     history = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connection.py:454, in HTTPConnection.getresponse(self)
#     451 from .response import HTTPResponse
#     453 # Get the response from http.client.HTTPConnection
# --> 454 httplib_response = super().getresponse()
#     456 try:
#     457     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
